# %%
import  pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import array, reshape, zeros, append, arange
import math
from math import log, e, pi
import numpy
from sys import argv

# %% [markdown]
# # Formation energy as  chemical potential vary

# %% [markdown]
#  #### Total Energies in eV

# %%
E0=-14644858.463124419 # pristine
E1=-14711404.113635940 # addon S
E2=-14578308.639903018 # mono S vacancy
E3=-14511759.369944071 # di S vacancy up&down
E4=-14511758.944663303 # di S vacancy neighboring
E5=-14192154.320500717 # mono Mo vacancy
E_WSe2=-585793.321771426 # primtitive
ESe8=-532375.657399940   #8 atoms in unitcell
mu_Se8=ESe8/8
EW=-905397.333160509 # Total energy in eV
mu_Wbcc=EW/2

# %% [markdown]
#  ## $$ E^{d}_{f}=E_{defect}(n_{i}+\Delta n_{i})-E_{pristine}(n_{i}) - \sum_{i} \Delta n_{i} \mu_{i} $$
#
# ## $$  E^{Bulk}_{WSe_{2}}-2\mu_{Se8} \leq \mu_{W} \leq \mu^{Bulk}_{W} $$
# ## $$ \frac{1}{2}(E_{WSe2}-\mu^{Bulk}_{W})\leq \mu_{Se} \leq \mu_{Se8} $$

# %%
mu_Se0_i=0.5*(E_WSe2-mu_Wbcc)
mu_W_i=E_WSe2-2*mu_Se8
mu_W_f=mu_Wbcc
mu_Se0_f=mu_Se8
mu_Se0=arange(mu_Se0_i,mu_Se0_f,0.05)
mu_W0=arange(mu_W_i,mu_W_f,0.05)

# %%
Ef_addSe =[] 
Ef_VSe = []
Ef_VSe2 =[]
Ef_VSe22=[]
Ef_W=[]

for i in mu_Se0:
    Ef_addSe.append(E1-E0-i) 
    Ef_VSe.append(E2-E0+i)
    Ef_VSe2.append(E3-E0+2*i) 
    Ef_VSe22.append(E4-E0+2*i)
 
for j in mu_W0:
    Ef_W.append(E5-E0+j)

plt.plot(mu_Se0-mu_Se0_f,Ef_addSe,'b', label='addon Se') 
plt.plot(mu_Se0-mu_Se0_f,Ef_VSe,'r', label='Mono Se vacancy') 
plt.plot(mu_Se0-mu_Se0_f,Ef_VSe22, 'g', label='di Se vacancy(neig)') 
plt.plot(mu_Se0-mu_Se0_f,Ef_VSe2, 'k', label='di Se vacancy(up&down)') 
#plt.plot(mu_Mo0-mu_Mo_f,Ef_Mo, 'yellow', label='Mono Mo vacancy') 
plt.xlabel('\Delta mu_Se', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=6)
plt.yticks(fontsize=10)
plt.tight_layout()


plt.savefig('Efvsmu_S.png',dpi=1200)

plt.show()

# %%
plt.plot(mu_W0-mu_W_f,Ef_W, 'yellow', label='Mono W vacancy') 
#plt.plot(T, VMo, 'yellow', label='Mono Mo vacany') 
plt.xlabel('\Delta mu_W', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=6)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.savefig('Efvsmu_W.png',dpi=1200)
plt.show()

# %%
T=arange(300,4100,100)
plt.plot(T, addS, 'b', label='addon Se')
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
#
plt.savefig('addSvsT.png',dpi=1200)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
plt.plot(T, VSe, 'r', label='Mono Se vacancy')
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
#
plt.yticks(fontsize=10)
plt.tight_layout()
#
plt.savefig('VSvsT.png',dpi=1200)
plt.show()
plt.plot(T, VSe22, 'g', label='di Se vacancy(neig)') 
plt.plot(T, VSe2, 'k', label='di Se vacancy(up&down)')

plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
#
plt.savefig('disvsT.png',dpi=1200)
plt.show()
##new_names=['{}x{}x{}'.format(i,i,i) for i in range(4, 18, 2)]
##plt.xticks(range(4, 18, 2), new_names, fontsize=16)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.plot(T, VW, 'yellow', label='Mono W vacany') 
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)

#
##new_names=['{}x{}x{}'.format(i,i,i) for i in range(4, 18, 2)]
##plt.xticks(range(4, 18, 2), new_names, fontsize=16)
plt.yticks(fontsize=10)
plt.tight_layout()
#
plt.savefig('Ef_3vsT.png',dpi=1200)
plt.show()

# %%
rho1=conc(addS)

#print(rho1)
rho2=conc(VSe)
#print(rho2)
rho3=conc(VSe22)
rho4=conc(VSe2)
rho5=conc(VW)
T=arange(300,4100,100)
plt.plot(1/T,np.log(rho1) , 'b', label='addon Se')
plt.xlabel('1/Temperature K-1', fontsize=12)
plt.ylabel('logarithm formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('addS2vsT.png',dpi=1200)
plt.show()
plt.plot(1/T, np.log(rho2), 'r', label='Mono Se vacancy') 
plt.xlabel('1/Temperature K-1', fontsize=12)
plt.ylabel('Logarithm of formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('VSSvsT.png',dpi=1200)
plt.show()
plt.plot(1/T, np.log(rho3), 'g', label='di Se vacancy(neig)') 
plt.xlabel('1/Temperature K-1', fontsize=12)
plt.ylabel('Logarithm of formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('VS22vsT.png',dpi=1200)
plt.show()
plt.plot(1/T, np.log(rho4), 'k', label='di Se vacancy(up&down)') 
plt.xlabel('1/Temperature K-1', fontsize=12)
plt.ylabel('Logarithm of Formation energy', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('VS2vsT.png',dpi=1200)
plt.show()
plt.plot(1/T, np.log(rho5), 'yellow', label='Mono W vacany') 
plt.xlabel('1/Temperature K-1', fontsize=12)
plt.ylabel('Logarithm of Formation energies', fontsize=12)
plt.legend(fontsize=8)
#
##new_names=['{}x{}x{}'.format(i,i,i) for i in range(4, 18, 2)]
##plt.xticks(range(4, 18, 2), new_names, fontsize=16)
#plt.yticks(fontsize=10)
#plt.tight_layout()
#
plt.show()

# %%
T=arange(300,4100,100)
plt.plot(T,rho1 , 'b', label='addon Se')
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('addS1vsT.png',dpi=1200)
plt.show()
plt.plot(T, rho2, 'r', label='Mono Se vacancy') 
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('VS1vsT.png',dpi=1200)
plt.show()
plt.plot(T, rho3, 'g', label='di Se vacancy(neig)') 
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('diS1vsT.png',dpi=1200)
plt.show()
plt.plot(T, rho4, 'k', label='di Se vacancy(up&down)') 
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.legend(fontsize=8)
plt.savefig('diS2vsT.png',dpi=1200)
plt.show()
plt.plot(T, rho5, 'yellow', label='Mono W vacany') 
plt.xlabel('Temperature K', fontsize=12)
plt.ylabel('Formation energies eV', fontsize=12)
plt.savefig('VMo2vsT.png',dpi=1200)
plt.legend(fontsize=8)
#
##new_names=['{}x{}x{}'.format(i,i,i) for i in range(4, 18, 2)]
##plt.xticks(range(4, 18, 2), new_names, fontsize=16)
#plt.yticks(fontsize=10)
#plt.tight_layout()
#
plt.show()
